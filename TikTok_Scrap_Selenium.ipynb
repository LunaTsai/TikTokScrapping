# %%
#Data Scrapping using selenium
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time

# Setting up the Chrome driver
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

# Navigating to the TikTok page
driver.get('https://www.tiktok.com/foryou')

# Scroll down the page multiple times to load more content
scroll_pause_time = 2  # Time in seconds between scrolls
screen_height = driver.execute_script("return window.screen.height;")  # Get the screen height

i = 0
while i < 3:  # Scroll 3 times, adjust if needed
    driver.execute_script("window.scrollTo(0, {0});".format(screen_height))
    time.sleep(scroll_pause_time)
    screen_height += screen_height
    i += 1

# Get the page source after content is loaded
page_source = driver.page_source

# Close the driver
driver.quit()

# Parse the webpage content using BeautifulSoup
soup = BeautifulSoup(page_source, 'html.parser')

# Extract and print the text inside the <body> tag
body = soup.body
print(f'Body: {body.text}')
# Out:
# Body:  Skip to content feedTikTokUpload Log inFor YouFollowingExploreNewLIVEProfileLog in to follow creators, like videos, and view comments.Log inCreate effectsAboutNewsroomContactCareersTikTok for GoodAdvertiseTikTok LIVE Creator NetworksDevelopersTransparencyTikTok RewardsTikTok EmbedsHelpSafetyTermsPrivacyCreator PortalCommunity GuidelinesSee more© 2023 TikTokmdmotivatorZachery DereniowskiFollowmore“We really need the money” 🥹❤️ #concert  #money  #akon  #surprise  #strangers  #christmas  #love  #music  original sound - Zachery DereniowskiClick to expand view1M588144K3020discelebsSatisfying ASMR CompilationFollowmoreASMR Random Kitchen Restock 🍉🍓 cr: @Naomi Victoria 🧦🧸🍂  @CarissaCleansItAll  @Victoria  #kitchenrestock  #randomrestock  #asmr  #restockasmr  #restockwithme  #organizedhome  #organizewithme  Kawaii Aesthetic - LoESClick to expand view830.9K263452.8K2104dubaitvDubaiTVFollowmoreالأداء المبهر لحنين الشاطر يُشعل الغيرة لدى أنغام   #اكس_فاكتور  #اكس_فاكتور_2023  #xfactor  #
# ...

# %%
#Data Scrapping using selenium(with IPs in France)
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time

# Setting up the Chrome driver
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

# Navigating to the TikTok page
driver.get('https://www.tiktok.com/foryou')

# Scroll down the page multiple times to load more content
scroll_pause_time = 10  # Time in seconds between scrolls
screen_height = driver.execute_script("return window.screen.height;")  # Get the screen height

i = 0
while i < 3:  # Scroll 3 times, adjust if needed
    driver.execute_script("window.scrollTo(0, {0});".format(screen_height))
    time.sleep(scroll_pause_time)
    screen_height += screen_height
    i += 1

# Get the page source after content is loaded
page_source = driver.page_source

# Close the driver
driver.quit()

# Parse the webpage content using BeautifulSoup
soup = BeautifulSoup(page_source, 'html.parser')

# Extract and print the text inside the <body> tag
body = soup.body
print(f'Body: {body.text}')
# Out:
# Body:  Skip to content feedTikTokUpload Log inFor YouFollowingExploreNewLIVEProfileLog in to follow creators, like videos, and view comments.Log inCreate effectsAboutNewsroomContactCareersTikTok for GoodAdvertiseTikTok LIVE Creator NetworksDevelopersTransparencyTikTok RewardsTikTok EmbedsHelpSafetyTermsPrivacyCreator PortalCommunity GuidelinesSee more© 2023 TikTokLIVELIVEla.faleteeela.faleteFollowmoresunet original - ⚜️𝓛𝓮𝓰𝓲𝓵𝓮 𝓵𝓾𝓲 𝓜⚜️86.7K429813.3K25KclemencesvanclFollowmoreLittle Women ft. Agape - lulu469232171ShareazulpodcastAzul podcast بودكاست أزولFollowmoreReplying to @Sãlløümå Iyëd   رأينا في الصداقة بعد الحب ❤️‍🩹هل توافقونا؟ #azul_podcast  #PodTok  #بودكاست_أزول  original sound - Azul podcast بودكاست أزول21911220111edysson94EdyssønFollowmoreDrunk in Love (feat. Jay-Z) - Beyoncé15K811279123burika.aepBurika.aepFollowmoreShot Power 🥶 #ronaldo  #cristianoronaldo  #cristiano  #football  #juventus Burika.aep - orijinal ses - Burika.aep50642592470detectivefileDetectiveFileFollowmoreGy
# ...

# %%
#Data Scrapping using selenium(with IPs in HongKong)
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time

# Setting up the Chrome driver
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

# Navigating to the TikTok page
driver.get('https://www.tiktok.com/foryou')

# Scroll down the page multiple times to load more content
scroll_pause_time = 10  # Time in seconds between scrolls
screen_height = driver.execute_script("return window.screen.height;")  # Get the screen height

i = 0
while i < 3:  # Scroll 3 times, adjust if needed
    driver.execute_script("window.scrollTo(0, {0});".format(screen_height))
    time.sleep(scroll_pause_time)
    screen_height += screen_height
    i += 1

# Get the page source after content is loaded
page_source = driver.page_source

# Close the driver
driver.quit()

# Parse the webpage content using BeautifulSoup
soup = BeautifulSoup(page_source, 'html.parser')

# Extract and print the text inside the <body> tag
body = soup.body
print(f'Body: {body.text}')
# Out:
# Body:
#
#
#
#
#
#
#
#
#
# Dear Users,
#
#                 We regret to inform you that we have discontinued operating TikTok in Hong Kong.
#
#
#                 Thank you for the time you have spent with us on the platform and for giving us the opportunity to bring a little bit of joy into your life.
#
#
#                 The TikTok Team
#
#
#
#
# Term of Use
# Copyright Policy
# Privacy Policy

# %%
#Data Scrapping using selenium(with IPs in Korea)
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time

# Setting up the Chrome driver
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

# Navigating to the TikTok page
driver.get('https://www.tiktok.com/foryou')

# Scroll down the page multiple times to load more content
scroll_pause_time = 10  # Time in seconds between scrolls
screen_height = driver.execute_script("return window.screen.height;")  # Get the screen height

i = 0
while i < 3:  # Scroll 3 times, adjust if needed
    driver.execute_script("window.scrollTo(0, {0});".format(screen_height))
    time.sleep(scroll_pause_time)
    screen_height += screen_height
    i += 1

# Get the page source after content is loaded
page_source = driver.page_source

# Close the driver
driver.quit()

# Parse the webpage content using BeautifulSoup
soup = BeautifulSoup(page_source, 'html.parser')

# Extract and print the text inside the <body> tag
body = soup.body
print(f'Body: {body.text}')
# Out:
# Body:  Skip to content feedTikTokUpload Log inFor YouFollowingExploreNewLIVEProfileLog in to follow creators, like videos, and view comments.Log inCreate effectsAboutNewsroomContactCareersTikTok for GoodAdvertiseTikTok LIVE Creator NetworksDevelopersTransparencyTikTok RewardsTikTok EmbedsHelpSafetyTermsPrivacyCreator PortalCommunity GuidelinesSee more© 2023 TikTokIntroducing keyboard shortcuts!Go to previous videoGo to next videoLike video Mute / unmute video Get appGet TikTok for desktopGet TikTok AppLog in to TikTokUse QR codeUse phone / email / usernameContinue with KakaoTalkContinue with GoogleContinue with FacebookContinue with TwitterContinue with LINEContinue with AppleBy continuing with an account located in  South Korea, you agree to our  Terms of Service and acknowledge that you have read our  Privacy Policy.Don’t have an account?  Sign up

# %%
#Data Scrapping using selenium(with IPs in Korea-2)
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time

# Setting up the Chrome driver
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

# Navigating to the TikTok page
driver.get('https://www.tiktok.com/foryou')

# Scroll down the page multiple times to load more content
scroll_pause_time = 10  # Time in seconds between scrolls
screen_height = driver.execute_script("return window.screen.height;")  # Get the screen height

i = 0
while i < 3:  # Scroll 3 times, adjust if needed
    driver.execute_script("window.scrollTo(0, {0});".format(screen_height))
    time.sleep(scroll_pause_time)
    screen_height += screen_height
    i += 1

# Get the page source after content is loaded
page_source = driver.page_source

# Close the driver
driver.quit()

# Parse the webpage content using BeautifulSoup
soup = BeautifulSoup(page_source, 'html.parser')

# Extract and print the text inside the <body> tag
body = soup.body
print(f'Body: {body.text}')
# Out:
# Body:  Skip to content feedTikTokUpload Log inFor YouFollowingExploreNewLIVEProfileLog in to follow creators, like videos, and view comments.Log inCreate effectsAboutNewsroomContactCareersTikTok for GoodAdvertiseTikTok LIVE Creator NetworksDevelopersTransparencyTikTok RewardsTikTok EmbedsHelpSafetyTermsPrivacyCreator PortalCommunity GuidelinesSee more© 2023 TikTokycn_videographer영찍남 / YCN🇰🇷FollowmoreThe Elevator (엘레베이터)오리지널 사운드  - 영찍남 / YCN🇰🇷7.6M31K711.8K20.5KredbullRed BullFollowmorethese cycle lanes are getting out of control 😏  #redbull  #givesyouwiiings  #redbullstalenros  #cycling  #bike  #netherlands  #funny  original sound - Red Bull6.4M25.4K309.3K69.1Kttless.smileshiprcingFollowmore😱😱 OMG 😱😱 #amazing  #bigships  #roughsea  #ocean  #bigwaves Hoist the Colours - Bass Singers Version - Bobby Bass4.2M22.2K221K22.1Kvantoan___VanFollowmoreWait for it 🥹❤️  I was playing the piano when suddenly, a 8 years old girl asked me to play « River Flows in you » and then she played with me ! 
# ...

# %%
#Data Scrapping using selenium(with IPs in Taiwan-1)
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time

# Setting up the Chrome driver
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

# Navigating to the TikTok page
driver.get('https://www.tiktok.com/foryou')

# Scroll down the page multiple times to load more content
scroll_pause_time = 10  # Time in seconds between scrolls
screen_height = driver.execute_script("return window.screen.height;")  # Get the screen height

i = 0
while i < 3:  # Scroll 3 times, adjust if needed
    driver.execute_script("window.scrollTo(0, {0});".format(screen_height))
    time.sleep(scroll_pause_time)
    screen_height += screen_height
    i += 1

# Get the page source after content is loaded
page_source = driver.page_source

# Close the driver
driver.quit()

# Parse the webpage content using BeautifulSoup
soup = BeautifulSoup(page_source, 'html.parser')

# Extract and print the text inside the <body> tag
body = soup.body
print(f'Body: {body.text}')
# Out:
# Body:  Skip to content feedTikTokUpload Log inFor YouFollowingExploreNewLIVEProfileLog in to follow creators, like videos, and view comments.Log inCreate effectsAboutNewsroomContactCareersTikTok for GoodAdvertiseTikTok LIVE Creator NetworksDevelopersTransparencyTikTok RewardsTikTok EmbedsHelpSafetyTermsPrivacyCreator PortalCommunity GuidelinesSee more© 2023 TikTokaalexiaevellynAlexia EvellynFollowmoreI’m amazed by the sound and beauty of this place 🥲 Pico das Agulhas Negras, certainly one of the greatest echoes I’ve ever heard in this life ⛰️  ••• Estou admirada com o som e a beleza desse lugar 🥲  Pico das Agulhas Negras, com certeza um dos maiores ecos que já ouvi nessa vida ⛰️  #mountains  #montana  #echo  #ancestralidade  #witch  original sound - Alexia Evellyn7.8M40.6K806.5K34Kmt2____MT2___Followmore#meme  original sound - MT2___5.2M36.9K440.2K116.9Kszayel.x_Szayel.xFollowmoreThese dolls are scary 🤯 #giant  #giantpuppet  #sea  #fyp  Hoist the Colours - Bass Singers Version - Bobb
# ...

# %%
#Data Scrapping using selenium(with IPs in Canada-1)
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time

# Setting up the Chrome driver
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

# Navigating to the TikTok page
driver.get('https://www.tiktok.com/foryou')

# Scroll down the page multiple times to load more content
scroll_pause_time = 10  # Time in seconds between scrolls
scrolls = 30  # Define the number of scrolls

for i in range(scrolls):
    # Scroll down to the bottom of the page
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(scroll_pause_time)

# Get the page source after content is loaded
page_source = driver.page_source

# Close the driver
#driver.quit()

# Process the page source using BeautifulSoup to print body text
soup = BeautifulSoup(page_source, 'html.parser')

# Find the body text and print it
body_text = soup.body.get_text()
print(body_text)
# Out:
#  Skip to content feedTikTokUpload Log inFor YouFollowingExploreNewLIVEProfileLog in to follow creators, like videos, and view comments.Log inCreate effectsAboutNewsroomContactCareersTikTok for GoodAdvertiseTikTok LIVE Creator NetworksDevelopersTransparencyTikTok RewardsTikTok EmbedsHelpSafetyTermsPrivacyCreator PortalCommunity GuidelinesSee more© 2023 TikTokcarolinakowanzCarolina KowanzFollowmore✈️ Flying with Mike🫠 Any similarity with fictitious events or characters was purely coincidental.😅😂 #airport  #fly  #english  #ingles original sound - Carolina KowanzCapCut | Edit like a pro757.7K100443K773asmrquiropraxiaASMR QUIROPRAXIAFollowmoreCAT CHIROPRACTIC #chiropractic  #chiropractor  #satisfying  #asmr  #foryou  #fyp  #cataoftiktok  #catlover  #cat  #gato  #quiropraxia  som original - ASMR QUIROPRAXIACapCut | Edit like a pro579.8K300746.4K3260vonartiniVon ArtiniFollowmoreWould u pass the loyalty test🤣❤️ #fyp  #foryou  original sound - Von Artini207.2K145414.6K4519LIVELIVEdicquewuopam
# ...

# %%
#Data Scrapping using selenium(with IPs in Rusia)
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time

# Setting up the Chrome driver
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

# Navigating to the TikTok page
driver.get('https://www.tiktok.com/foryou')

# Scroll down the page multiple times to load more content
scroll_pause_time = 10  # Time in seconds between scrolls
scrolls = 5  # Define the number of scrolls

for i in range(scrolls):
    # Scroll down to the bottom of the page
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(scroll_pause_time)

# Get the page source after content is loaded
page_source = driver.page_source

# Close the driver
driver.quit()

# Process the page source using BeautifulSoup to print body text
soup = BeautifulSoup(page_source, 'html.parser')

# Find the body text and print it
body_text = soup.body.get_text()
print(body_text)
# Out:
#  Skip to content feedTikTokUpload Log inFor YouFollowingExploreNewProfileLog in to follow creators, like videos, and view comments.Log inCreate effectsAboutNewsroomContactCareersTikTok for GoodAdvertiseTikTok LIVE Creator NetworksDevelopersTransparencyTikTok RewardsTikTok EmbedsHelpSafetyTermsPrivacyCreator PortalCommunity GuidelinesSee more© 2023 TikTokpopovrtrEvgeny  PopovFollowmore#депутат #госдума #хайп  #хеллоуин  #halloween2023 original sound  - Evgeny  PopovMoscow18.4K1502501265zhivyye_oboiLive wallpaperFollowmore@NAVIN THAPA  #livewallpaper  #livewallpaper4k  #4k  #4klivewallpaper  #livewallpapers  #wallpaper  #wallpapers  #ライブ壁紙  #ライブ壁紙4K  #livenawallpaper  #papeldeparedeaovivo  #hìnhnềnsống  #жандытұсқағаз  #живыеобои  #خلفيةحية  #動態壁紙  #wallpaper  #wallpapers  #smmupdates  #fondodepantalla  #fondodepantallaanimado  #fondosdepantalla4k  #longervideos  #라이브배경화면  #hìnhnềnsống  #लाइववॉलपेपर  #लाइववॉलपेपर4k  #ζωντανήταπετσαρία  #sfondianimati  #gyvitapetai  #longervideos  #edit
# ...

# %%
#Data Scrapping using selenium(with IPs in Taiwan, scraped for longer time)
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time

# Setting up the Chrome driver
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

# Navigating to the TikTok page
driver.get('https://www.tiktok.com/foryou')

# Scroll down the page multiple times to load more content
scroll_pause_time = 60   # Time in seconds between scrolls
scrolls = 75  # Define the number of scrolls

for i in range(scrolls):
    # Scroll down to the bottom of the page
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(scroll_pause_time)

# Get the page source after content is loaded
page_source = driver.page_source

# Close the driver
driver.quit()

# Process the page source using BeautifulSoup to print body text
soup = BeautifulSoup(page_source, 'html.parser')

# Find the body text and print it
body_text = soup.body.get_text()
print(body_text)
# Out:
#  Skip to content feedTikTokUpload Log inFor YouFollowingExploreNewLIVEProfileLog in to follow creators, like videos, and view comments.Log inCreate effectsAboutNewsroomContactCareersTikTok for GoodAdvertiseTikTok LIVE Creator NetworksDevelopersTransparencyTikTok RewardsTikTok EmbedsHelpSafetyTermsPrivacyCreator PortalCommunity GuidelinesSee more© 2024 TikTokh_oonjiyeriFollowmore#douyin抖音  Closer by Aash Mehta Flip - Líng Yue7.8M27.3K594.9K55.7Kseventeen17_officialSEVENTEENFollowmore#wopchallenge  😎original sound - Slim 199x7.3M78.4K594.8K108.2Khorror.rooms.dubaiHorror Rooms by NoWayOutFollowmoreScariest escape games in Dubai - Horror Rooms! Book now, link in bio! original sound - LightskinMonte4.2M6407386.2K31.9KaalexiaevellynAlexia EvellynFollowmoreI’m amazed by the sound and beauty of this place 🥲 Pico das Agulhas Negras, certainly one of the greatest echoes I’ve ever heard in this life ⛰️   •••  Estou admirada com o som e a beleza desse lugar 🥲  Pico das Agulhas Negras, com certez
# ...
